# %% [markdown]
# # Lab 1: Working with OpenAI API and Reasoning Models
#
# ### Overview
#
# And now comes the fun part!!! Let's get our hands dirty with calling the ChatGPT models using code.
#
# This notebook demonstrates how to use the OpenAI API to create various AI-powered applications. We'll explore how to structure prompts, understand API responses, and evaluate model outputs using reasoning capabilities.
#
# ### Objectives
# - Set up and configure the OpenAI API with proper authentication
# - Create effective prompts for different use cases
# - Process and display AI-generated responses
# - Compare standard chat models with reasoning models
#
#
# ### **Important Note** for Windows users:
#
# When trying to activate your virtual environment, you may run into an error looking something like this
#
# ```
# ai_env\Scripts\activate : File C:\Users\<username>\OneDrive\Desktop\ai-engineering\ai_env\Scripts\Activate.ps1 cannot be loaded because running scripts is disabled on this system.
#
# For more information, see about_Execution_Policies at https:/go.microsoft.com/fwlink/?LinkID=135170
# ```
#
#
# The reason for this is because by default, Microsoft disables the ability to execute the scripts. To overcome this,
#
# 1. open up PowerShell (terminal)
# 2. Run the following command: `Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser`
# 3. Close and re-open PowerShell (restart your machine if you have to)
# 4. Try activating the environment again by:
#     - Navigating to the root directory of the project (the ai-engineering folder)
#     - Run `ai_env/Scripts/Activate`
#
#
# If you still aren't able to overcome the issue, please follow the instructions in the [README](../../../README.md) to either raise an issue on GitHub or contact me via email or on the SDS platform.

# %% [markdown]
# #### Step 1: Import libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")

# %% [markdown]
# #### Step 2: Call the API

# %%
client = OpenAI()
response = client.chat.completions.create(
    model = "gpt-4o-mini",
    messages = [
        {"role":"system", "content":"You are an assistant"},
        {"role":"user", "content": "Why dont it snow in summer"}
    ],
    temperature=0.6,
    max_tokens=100
)
print(response.choices[0].message.content)
# Out:
# Snow forms when temperatures are low enough for water vapor in the atmosphere to freeze into ice crystals. This typically occurs when the air temperature is at or below 0 degrees Celsius (32 degrees Fahrenheit). During the summer months, temperatures are generally much warmer, often well above freezing, which prevents snow from forming.
#
# However, in some high-altitude or polar regions, it can still snow during the summer. For example, areas like the Arctic or high mountain ranges can experience snow even in the warmer months,

# %% [markdown]
# #### Message list

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "What is the capital of France?"},
    {"role": "assistant", "content": "The capital of France is Paris."},
    {"role": "user", "content": "What is the population of Paris?"},
    {"role": "assistant", "content": "As of 2021, the population of Paris is approximately 2.1 million people."}
]

# %% [markdown]
# #### Step 3: Customize the User Prompt
#
# Find the best career suited to you

# %%
system_message = "You are a career advisor. Help the user find their ideal career based on their skillset, current industry, interests, and objectives."

user_prompt = """
Help me find my ideal career based on the following:

1. My Skillset
- PySpark
- SQL
- PowerBI

2. My current industry
- IT

3. My interests
- Data Analytics
- Machine Learning
- AI/ML

4. My objectives
- A high paying job
- Work-life balance
- job security

Now based on this, give me:
- 1 career recommendation
- why you think this is a good fit for me
- steps to take to achieve this career goal
"""
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_prompt}
    ],
)       
display(Markdown(completion.choices[0].message.content))
# Out:
# Based on your skill set, current industry, interests, and objectives, I recommend considering a career as a **Data Scientist**.
#
# ### Why This is a Good Fit for You:
# 1. **Skill Alignment**: Your skills in PySpark, SQL, and Power BI directly align with the requirements of a Data Scientist role. Data Science often requires the manipulation and analysis of large data sets and the use of visualization tools, which you already have experience with.
#
# 2. **Interest in Data Analytics and AI/ML**: Data Science is largely centered around these areas. Your passion for data analytics, machine learning, and AI makes this role not just a good fit but also one that you are likely to enjoy and find fulfilling.
#
# 3. **Career Demand and Salary**: The demand for Data Scientists continues to grow across various industries. As companies seek to leverage data for competitive advantage, this role has high earning potential, meets your objective for a high-paying job, and generally provides opportunities for job security.
#
# 4. **Flexibility and Work-Life Balance**: Many organizations offer remote work options or flexible hours for Data Science roles, allowing for a better work-life balance.
#
# ### Steps to Achieve Your Career Goal:
# 1. **Enhance Your Skills**:
#    - Consider learning relevant programming languages like Python (if you aren’t familiar yet) as it’s widely used in data science.
#    - Deepen your understanding of machine learning algorithms and statistical analysis.
#
# 2. **Build a Portfolio**:
#    - Work on personal projects or collaborate on open-source projects. Utilize your current data analytics skills to conduct analyses and build models. Document these projects well.
#    - Create case studies showcasing your ability to derive insights from data and effectively communicate them using Power BI visualizations.
#
# 3. **Certifications and Courses**:
#    - Look into certifications such as Data Science or Machine Learning courses from reputable platforms (e.g., Coursera, edX, or DataCamp). Consider obtaining a certification from recognized organizations like Microsoft or AWS that focus on data analytics and machine learning.
#
# 4. **Networking and Community Involvement**:
#    - Attend meetups, webinars, and workshops focused on data science, analytics, and AI/ML. Joining professional groups or online communities (like LinkedIn groups) can provide valuable connections and insight into the industry.
#
# 5. **Gain Relevant Experience**:
#    - Seek opportunities within your current organization to work on data-centric projects. Consider transitioning into a data-focused role if available. Internships or freelance gigs in data analysis or data science can be beneficial as well.
#
# 6. **Job Search Preparation**:
#    - Revamp your CV and LinkedIn profile to highlight your skills, relevant experiences, and projects.
#    - Prepare for interviews by studying common data science interview questions and practices, focusing specifically on problem-solving and case study scenarios.
#
# By following these steps, you can transition into a Data Scientist role effectively while aligning with your interests and objectives for a successful and sustainable career.

# %% [markdown]
# #### Step 4: Build a plan for your career path

# %%
# Step 1: Use your chat model result and copy/paste your career suggestion below
career_suggestion = completion.choices[0].message.content
# Step 2: Write a reasoning prompt that will help the model plan how to pursue this career
# Your prompt must:
# - Refer to the user's profile + their chosen career
# - Ask for a step-by-step plan
# - Include at least 3 types of guidance (e.g. skills, resources, milestones)
reasoning_prompt = f"""
I have been given the following career suggestion based on my profile: {career_suggestion}
Here is my profile again for reference: {user_prompt}
provide me with a step-by-step plan to pursue this career. Include guidance on skills I should acquire, resources I can use, and milestones I should aim for.
"""  # TODO: Write this yourself


completion = client.chat.completions.create(
    model="o3-mini",
    messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": reasoning_prompt}
    ]
) 

reasoning_response = completion.choices[0].message.content
display(Markdown(reasoning_response))
# Out:
# Based on your background in IT and your current skillset (PySpark, SQL, PowerBI) combined with your interest in Data Analytics, Machine Learning, and AI/ML—and considering your objectives of landing a high-paying, secure job that also supports work–life balance—I recommend pursuing a career as a Data Scientist with a focus on applied Machine Learning.
#
# Why This Is a Good Fit for You:
#
# • Your strong foundation in data manipulation and visualization (through SQL and PowerBI) is an excellent starting point for data science.
# • PySpark experience gives you an edge in handling large datasets, a skill that’s in high demand among data scientists dealing with big data.
# • Transitioning into a data science role that emphasizes machine learning and AI/ML leverages your interests and sets you on a path toward highly compensated and secure roles.
# • Data science positions, especially those involving ML/AI, often offer good work–life balance with many companies now investing in robust data teams and flexible work policies.
#
# Below is a step-by-step plan to help you make this transition:
#
# ──────────────────────────────
# Phase 1: Strengthen Your Core Foundations
#
# 1. Enhance Your Programming and Statistics Skills:
#    • Build on your existing Python experience: deepen your proficiency with libraries such as Pandas, NumPy, and Matplotlib.
#    • Refresh and expand your knowledge of key mathematical concepts—linear algebra, statistics, and probability—which are essential for data science.
#    • Resources:
#      - Python: “Python for Everybody” (Coursera), Codecademy’s Python course.
#      - Mathematics/Statistics: Khan Academy’s statistics courses, MIT OpenCourseWare.
#    • Milestones:
#      - Complete intermediate Python exercises focusing on data manipulation.
#      - Finish a statistics module and apply concepts to sample datasets.
#
# ──────────────────────────────
# Phase 2: Learn Data Science and Machine Learning Fundamentals
#
# 2. Acquire Core Data Science and Machine Learning Skills:
#    • Dive into data wrangling: build on your SQL and PySpark skills—you already know how to handle large data sets.
#    • Learn machine learning fundamentals: get comfortable with supervised and unsupervised learning algorithms using libraries like scikit-learn.
#    • Practice data visualization: while you work with PowerBI, also explore Python visualization tools (matplotlib, seaborn) for research and experimentation.
#    • Resources:
#      - Online Courses: Coursera’s “Applied Data Science with Python” specialization, Udacity’s Data Scientist Nanodegree, or edX’s professional certificates.
#      - Books: “Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow” by Aurélien Géron.
#    • Milestones:
#      - Complete an introductory machine learning course.
#      - Create 1–2 small projects or notebooks applying ML algorithms to real public datasets.
#      - Integrate data visualization into your analysis reports.
#
# ──────────────────────────────
# Phase 3: Gain Hands-On Experience
#
# 3. Build Projects and Participate in Competitions:
#    • Design projects that combine data extraction, cleaning, analysis, and ML model building.
#    • Leverage platforms like Kaggle to work on competitions or public datasets, further validating your skills.
#    • Start incorporating end-to-end projects that can be showcased on your GitHub or personal portfolio website.
#    • Resources:
#      - Kaggle (competitions and community datasets).
#      - GitHub: Use it to host and share your project code.
#    • Milestones:
#      - Complete 3–5 projects covering various stages of the data science lifecycle.
#      - Participate in at least one Kaggle competition.
#      - Develop a portfolio website summarizing your project work.
#
# ──────────────────────────────
# Phase 4: Deepen Your Specialization in Machine Learning/AI
#
# 4. Advance Your Machine Learning and AI Skills:
#    • Dive deeper into advanced topics, such as deep learning (using frameworks like TensorFlow or PyTorch), natural language processing, or time series analysis, to better position yourself in the competitive AI/ML space.
#    • Learn about model deployment and scalability so you can turn your models into production-ready services.
#    • Resources:
#      - Advanced Courses: Deep Learning Specialization (Coursera, by Andrew Ng), fast.ai courses.
#      - Books: “Deep Learning with Python” by François Chollet.
#      - Tutorials on deploying ML models: Explore Docker, Flask, and cloud platforms like AWS or Google Cloud.
#    • Milestones:
#      - Build an advanced ML project (e.g., an image recognition system or a natural language processing model).
#      - Experiment with deploying a model (for example, as a simple web service) and document the process.
#      - Update your portfolio to include these advanced projects.
#
# ──────────────────────────────
# Phase 5: Network, Intern, and Prepare for Your Job Search
#
# 5. Expand Your Professional Network and Industry Exposure:
#    • Engage with the data science community through meetups, LinkedIn groups, or data science conferences.
#    • Look for internships, freelance roles, or part-time projects that let you apply your new data science skills in a real-world setting.
#    • Polish your resume, emphasizing your project work, technical skills, and relevant industry experience.
#    • Resources:
#      - Networking platforms: LinkedIn, Data Science Meetups, and local tech communities.
#      - Job Boards: LinkedIn, Glassdoor, and specialized data science job platforms.
#    • Milestones:
#      - Secure an internship or freelance role in data science.
#      - Attend at least one professional networking event or conference.
#      - Prepare and participate in mock interviews focusing on both technical and project-based discussions.
#
# ──────────────────────────────
# Phase 6: Continuous Learning and Career Advancement
#
# 6. Develop a Routine for Ongoing Improvement:
#    • Set specific short-term (monthly), mid-term (quarterly), and long-term (yearly) goals and monitor your progress.
#    • Regularly seek out feedback on your projects and interview performance.
#    • Consider certifications or advanced courses that could further enhance your expertise and marketability.
#    • Milestones:
#      - Establish and review a learning schedule regularly.
#      - Update your portfolio and resume with each new project and achievement.
#      - Revisit industry trends and adjust your learning roadmap annually.
#
# ──────────────────────────────
# Final Thoughts
#
# Pursuing this career path as a Data Scientist with a focus on AI/ML allows you to leverage your existing experience in IT and data handling while expanding into areas that are both in high demand and highly compensated. The continuous development of your machine learning skills, combined with real-world project experience and networking, will position you for roles that meet your criteria for high pay, job security, and work–life balance.
#
# Good luck on your journey to this exciting and rewarding career—stay adaptable, be persistent, and constantly seek opportunities to apply what you learn!

# %% [markdown]
# # **Your Challenge!!!**

# %% [markdown]
# You’re helping your friend make a career switch. You’ve used a chat model to get a career recommendation, but now you need a solid action plan.
#
# **Challenge:**
#
# The prompt below is weak and unclear. Your task is to rewrite it so that it:
# - Clearly refers to your friend's profile and the suggested career
# - Asks for a step-by-step plan to pursue the career
# - Requests at least 3 types of guidance (e.g., skills to learn, resources to use, milestones to achieve)
# - Is specific, actionable, and easy for the model to follow
#
# Replace the flawed prompt in the next cell with your improved version in the cell after it and respond to the questions in "**Reflections**".

# %%
# Before
career_suggestion = """
Based on your profile, you would be a great UX Designer.
"""

# This is the flawed reasoning prompt
reasoning_prompt = f"""
Can you help me with this career? {career_suggestion}

"""

completion = client.chat.completions.create(
    model="o3-mini",
    messages=[
        {"role": "system", "content": system_message},
        {            "role": "user",
            "content": reasoning_prompt
        }
    ]
)

display(Markdown(completion.choices[0].message.content))

# %%
# After

# %% [markdown]
# ## **Reflections**
#
# 1. Identify 2-3 problems with the initial prompt.
#
# 2. What specific instructions or items did you add in your prompt which brought about the most change?
#
# 3. Is a chat model better for this use case or a reasoning model?
#
# 3. How did the answer differ when using a chat model vs. a reasoning model?
